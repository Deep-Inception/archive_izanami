# %%
# %%HTML
# <style>
#     div#notebook-container    { width: 100%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
# Out:
# <style>
#     div#notebook-container    { width: 100%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>

# %%
import collections
import datetime
import glob
import os
import re
import sqlite3
import time
import urllib

import lhafile
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder

COLUMN_LIST = ['RACE_TIME', 'RACER_ID', 'PLACE', 'DISTANCE', 'COURSE', 'EXHIBITION_TIME', 'RACE_DATE']

class RaceResults:
    def __init__(self):
        self.baseuri = "http://www1.mbrace.or.jp/od2/K/%s/k%s.lzh" # http://www1.mbrace.or.jp/od2/K/201612/k161201.lzh
        self.results = [] # List of (RACE_TIME, RACER_ID, PLACE, COURSE, EXHIBITION_TIME)

    def download(self, start, end):
        period = pd.date_range(start, end)

        for date in period:
            # Get file from the website
            dirname = date.strftime("%Y%m")
            lzhname = date.strftime("%y%m%d")
            uri = self.baseuri % (dirname, lzhname)
            savename = "./data/results/lzh/%s.lzh" % lzhname
            if not os.path.exists(savename):
                print("Send request to", uri)
                urllib.request.urlretrieve(uri, savename)
                time.sleep(3)

            unpackedpath = "./data/results/K%s.TXT" % lzhname
            unpackedname = os.path.basename(unpackedpath)
            if not os.path.exists(unpackedpath):
                print("Unpacking", savename)
                f = lhafile.Lhafile(savename)
                data = f.read(unpackedname)
                datastr = data.decode(encoding='shift-jis')
                fileobj = open(unpackedpath, "w")
                fileobj.write(datastr)
                fileobj.close()

    def load_and_regist(self):
        all_results = []
        for filename in glob.glob("./data/results/K*.TXT"):
            race_date_str = filename.replace("./data/results/K", "20").replace(".TXT","")
            tdatetime = datetime.datetime.strptime(race_date_str, '%Y%m%d')
            race_date = datetime.date(tdatetime.year, tdatetime.month, tdatetime.day)
            with open(filename, "r") as f:
                get_place = False
                get_racer_info = False
                count = 1
                race_time = 0
                for line in f:
                    line_replaced =  line.replace("\u3000", "")
                    if line_replaced.find('BGN') > -1:
                        get_place = True
                    elif get_place:
                        _place_index = line_replaced.find('［成績］')
                        place = line_replaced[0:_place_index]
                        get_place = False
                    elif re.search(r'H\d{4}m', line_replaced, flags=0)  is not None:
                        distance = re.search(r'\d{4}', line_replaced, flags=0).group()
                    elif line_replaced.startswith("----"):
                        get_racer_info = True
                    elif get_racer_info and count < 7:
                        elems = line_replaced.split()
                        if elems[0] not in ['01','02','03','04','05','06']:
                            count += 1
                            continue
                        if elems[9] != '.':
                            _race_time = elems[9].split('.')
                            race_time = float(_race_time[0])*60 + float(_race_time[1]) + float(_race_time[2])/10
                        else:
                            race_time = race_time + 1
                        racer_id = elems[2]
                        course = float(elems[1])
                        exhibition_time = float(elems[6])
                        if race_date.month == 1:
                            all_results.append((race_time, racer_id, place, distance, course, exhibition_time, race_date))
                        all_results.append((race_time, racer_id, place, distance, course, exhibition_time, race_date))
                        count += 1
                    elif count == 7:
                        count = 1
                        get_racer_info = False
                        
        self.results = all_results
        regist(self.results)
                                                            
    def get_results_pd(self):
        return pd.DataFrame(get_results(), columns=COLUMN_LIST)

# %%
column_list_type = "RACE_TIME REAL, RACER_ID TEXT, PLACE TEXT, DISTANCE INTEGER, COURSE INTEGER, EXHIBITION_TIME REAL, RACE_DATE TEXT"
column_list = "RACE_TIME, RACER_ID, PLACE, DISTANCE, COURSE, EXHIBITION_TIME, RACE_DATE"
dbname = "raceresults.db"

def regist(results):
    conn=sqlite3.connect(dbname)
    cursor = conn.cursor()

    drop_table = "DROP TABLE IF EXISTS raceresults"
    cursor.execute(drop_table)
    create_table = "CREATE TABLE raceresults (" + column_list_type + ")"
    cursor.execute(create_table)

    sql = "INSERT INTO raceresults (" + column_list + ") Values (?,?,?,?,?,?,?)"
    for item in results:
        cursor.execute(sql, item)
    conn.commit()
    conn.close()

def get_results():
    conn=sqlite3.connect(dbname)
    cursor = conn.cursor()
    get_records = "SELECT * FROM raceresults"
    cursor.execute(get_records)
    results = cursor.fetchall()
    conn.close()
    return results

# %%
if __name__ == "__main__":
    r = RaceResults()
    r.download("2019-10-01","2020-01-31")
    r.load_and_regist()
    a = r.get_results_pd()
# Out:
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191001.lzh
# Unpacking ./data/results/lzh/191001.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191002.lzh
# Unpacking ./data/results/lzh/191002.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191003.lzh
# Unpacking ./data/results/lzh/191003.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191004.lzh
# Unpacking ./data/results/lzh/191004.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191005.lzh
# Unpacking ./data/results/lzh/191005.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191006.lzh
# Unpacking ./data/results/lzh/191006.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191007.lzh
# Unpacking ./data/results/lzh/191007.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191008.lzh
# Unpacking ./data/results/lzh/191008.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191009.lzh
# Unpacking ./data/results/lzh/191009.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191010.lzh
# Unpacking ./data/results/lzh/191010.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191011.lzh
# Unpacking ./data/results/lzh/191011.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191012.lzh
# Unpacking ./data/results/lzh/191012.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191013.lzh
# Unpacking ./data/results/lzh/191013.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191014.lzh
# Unpacking ./data/results/lzh/191014.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191015.lzh
# Unpacking ./data/results/lzh/191015.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191016.lzh
# Unpacking ./data/results/lzh/191016.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191017.lzh
# Unpacking ./data/results/lzh/191017.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191018.lzh
# Unpacking ./data/results/lzh/191018.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191019.lzh
# Unpacking ./data/results/lzh/191019.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191020.lzh
# Unpacking ./data/results/lzh/191020.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191021.lzh
# Unpacking ./data/results/lzh/191021.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191022.lzh
# Unpacking ./data/results/lzh/191022.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191023.lzh
# Unpacking ./data/results/lzh/191023.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191024.lzh
# Unpacking ./data/results/lzh/191024.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191025.lzh
# Unpacking ./data/results/lzh/191025.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191026.lzh
# Unpacking ./data/results/lzh/191026.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191027.lzh
# Unpacking ./data/results/lzh/191027.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191028.lzh
# Unpacking ./data/results/lzh/191028.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191029.lzh
# Unpacking ./data/results/lzh/191029.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191030.lzh
# Unpacking ./data/results/lzh/191030.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201910/k191031.lzh
# Unpacking ./data/results/lzh/191031.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191101.lzh
# Unpacking ./data/results/lzh/191101.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191102.lzh
# Unpacking ./data/results/lzh/191102.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191103.lzh
# Unpacking ./data/results/lzh/191103.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191104.lzh
# Unpacking ./data/results/lzh/191104.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191105.lzh
# Unpacking ./data/results/lzh/191105.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191106.lzh
# Unpacking ./data/results/lzh/191106.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191107.lzh
# Unpacking ./data/results/lzh/191107.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191108.lzh
# Unpacking ./data/results/lzh/191108.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191109.lzh
# Unpacking ./data/results/lzh/191109.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191110.lzh
# Unpacking ./data/results/lzh/191110.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191111.lzh
# Unpacking ./data/results/lzh/191111.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191112.lzh
# Unpacking ./data/results/lzh/191112.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191113.lzh
# Unpacking ./data/results/lzh/191113.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191114.lzh
# Unpacking ./data/results/lzh/191114.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191115.lzh
# Unpacking ./data/results/lzh/191115.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191116.lzh
# Unpacking ./data/results/lzh/191116.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191117.lzh
# Unpacking ./data/results/lzh/191117.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191118.lzh
# Unpacking ./data/results/lzh/191118.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191119.lzh
# Unpacking ./data/results/lzh/191119.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191120.lzh
# Unpacking ./data/results/lzh/191120.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191121.lzh
# Unpacking ./data/results/lzh/191121.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191122.lzh
# Unpacking ./data/results/lzh/191122.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191123.lzh
# Unpacking ./data/results/lzh/191123.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191124.lzh
# Unpacking ./data/results/lzh/191124.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191125.lzh
# Unpacking ./data/results/lzh/191125.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191126.lzh
# Unpacking ./data/results/lzh/191126.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191127.lzh
# Unpacking ./data/results/lzh/191127.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191128.lzh
# Unpacking ./data/results/lzh/191128.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191129.lzh
# Unpacking ./data/results/lzh/191129.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201911/k191130.lzh
# Unpacking ./data/results/lzh/191130.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191201.lzh
# Unpacking ./data/results/lzh/191201.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191202.lzh
# Unpacking ./data/results/lzh/191202.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191203.lzh
# Unpacking ./data/results/lzh/191203.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191204.lzh
# Unpacking ./data/results/lzh/191204.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191205.lzh
# Unpacking ./data/results/lzh/191205.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191206.lzh
# Unpacking ./data/results/lzh/191206.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191207.lzh
# Unpacking ./data/results/lzh/191207.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191208.lzh
# Unpacking ./data/results/lzh/191208.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191209.lzh
# Unpacking ./data/results/lzh/191209.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191210.lzh
# Unpacking ./data/results/lzh/191210.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191211.lzh
# Unpacking ./data/results/lzh/191211.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191212.lzh
# Unpacking ./data/results/lzh/191212.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191213.lzh
# Unpacking ./data/results/lzh/191213.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191214.lzh
# Unpacking ./data/results/lzh/191214.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191215.lzh
# Unpacking ./data/results/lzh/191215.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191216.lzh
# Unpacking ./data/results/lzh/191216.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191217.lzh
# Unpacking ./data/results/lzh/191217.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191218.lzh
# Unpacking ./data/results/lzh/191218.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191219.lzh
# Unpacking ./data/results/lzh/191219.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191220.lzh
# Unpacking ./data/results/lzh/191220.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191221.lzh
# Unpacking ./data/results/lzh/191221.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191222.lzh
# Unpacking ./data/results/lzh/191222.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191223.lzh
# Unpacking ./data/results/lzh/191223.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191224.lzh
# Unpacking ./data/results/lzh/191224.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191225.lzh
# Unpacking ./data/results/lzh/191225.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191226.lzh
# Unpacking ./data/results/lzh/191226.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191227.lzh
# Unpacking ./data/results/lzh/191227.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191228.lzh
# Unpacking ./data/results/lzh/191228.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191229.lzh
# Unpacking ./data/results/lzh/191229.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191230.lzh
# Unpacking ./data/results/lzh/191230.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/201912/k191231.lzh
# Unpacking ./data/results/lzh/191231.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200106.lzh
# Unpacking ./data/results/lzh/200106.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200107.lzh
# Unpacking ./data/results/lzh/200107.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200108.lzh
# Unpacking ./data/results/lzh/200108.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200109.lzh
# Unpacking ./data/results/lzh/200109.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200110.lzh
# Unpacking ./data/results/lzh/200110.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200111.lzh
# Unpacking ./data/results/lzh/200111.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200112.lzh
# Unpacking ./data/results/lzh/200112.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200113.lzh
# Unpacking ./data/results/lzh/200113.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200114.lzh
# Unpacking ./data/results/lzh/200114.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200115.lzh
# Unpacking ./data/results/lzh/200115.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200116.lzh
# Unpacking ./data/results/lzh/200116.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200117.lzh
# Unpacking ./data/results/lzh/200117.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200118.lzh
# Unpacking ./data/results/lzh/200118.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200119.lzh
# Unpacking ./data/results/lzh/200119.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200120.lzh
# Unpacking ./data/results/lzh/200120.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200121.lzh
# Unpacking ./data/results/lzh/200121.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200122.lzh
# Unpacking ./data/results/lzh/200122.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200123.lzh
# Unpacking ./data/results/lzh/200123.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200124.lzh
# Unpacking ./data/results/lzh/200124.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200125.lzh
# Unpacking ./data/results/lzh/200125.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200126.lzh
# Unpacking ./data/results/lzh/200126.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200127.lzh
# Unpacking ./data/results/lzh/200127.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200128.lzh
# Unpacking ./data/results/lzh/200128.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200129.lzh
# Unpacking ./data/results/lzh/200129.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200130.lzh
# Unpacking ./data/results/lzh/200130.lzh
# Send request to http://www1.mbrace.or.jp/od2/K/202001/k200131.lzh
# Unpacking ./data/results/lzh/200131.lzh

# %%
a
# Out:
#         RACE_TIME RACER_ID PLACE  DISTANCE  COURSE  EXHIBITION_TIME  \
# 0           106.3     4715    芦屋      1800       2             6.72
# 1           106.3     4715    芦屋      1800       2             6.72
# 2           107.7     4342    芦屋      1800       1             6.70
# 3           107.7     4342    芦屋      1800       1             6.70
# 4           109.4     5017    芦屋      1800       5             6.74
# 5           109.4     5017    芦屋      1800       5             6.74
# 6           109.6     3286    芦屋      1800       3             6.68
# 7           109.6     3286    芦屋      1800       3             6.68
# 8           110.6     4365    芦屋      1800       4             6.72
# 9           110.6     4365    芦屋      1800       4             6.72
# 10          111.6     3257    芦屋      1800       6             6.72
# 11          111.6     3257    芦屋      1800       6             6.72
# 12          106.0     4445    芦屋      1800       4             6.74
# 13          106.0     4445    芦屋      1800       4             6.74
# 14          107.4     3831    芦屋      1800       3             6.72
# 15          107.4     3831    芦屋      1800       3             6.72
# 16          109.6     4581    芦屋      1800       1             6.75
# 17          109.6     4581    芦屋      1800       1             6.75
# 18          111.3     3231    芦屋      1800       2             6.76
# 19          111.3     3231    芦屋      1800       2             6.76
# 20          112.3     4047    芦屋      1800       6             6.73
# 21          112.3     4047    芦屋      1800       6             6.73
# 22          106.7     4463    芦屋      1800       1             6.67
# 23          106.7     4463    芦屋      1800       1             6.67
# 24          107.2     4061    芦屋      1800       3             6.71
# 25          107.2     4061    芦屋      1800       3             6.71
# 26          110.0     4138    芦屋      1800       2             6.74
# 27          110.0     4138    芦屋      1800       2             6.74
# 28          110.2     3548    芦屋      1800       5             6.75
# 29          110.2     3548    芦屋      1800       5             6.75
# ...           ...      ...   ...       ...     ...              ...
# 140213      112.2     4435   多摩川      1800       1             6.78
# 140214      112.2     4435   多摩川      1800       1             6.78
# 140215      113.2     3200   多摩川      1800       2             6.78
# 140216      113.2     3200   多摩川      1800       2             6.78
# 140217      114.2     5034   多摩川      1800       3             6.85
# 140218      114.2     5034   多摩川      1800       3             6.85
# 140219      115.2     3602   多摩川      1800       6             6.79
# 140220      115.2     3602   多摩川      1800       6             6.79
# 140221      109.9     4037   多摩川      1800       3             6.78
# 140222      109.9     4037   多摩川      1800       3             6.78
# 140223      110.9     3550   多摩川      1800       6             6.74
# 140224      110.9     3550   多摩川      1800       6             6.74
# 140225      112.2     4466   多摩川      1800       4             6.68
# 140226      112.2     4466   多摩川      1800       4             6.68
# 140227      112.8     3220   多摩川      1800       2             6.79
# 140228      112.8     3220   多摩川      1800       2             6.79
# 140229      113.8     3718   多摩川      1800       5             6.77
# 140230      113.8     3718   多摩川      1800       5             6.77
# 140231      108.6     4030   多摩川      1800       1             6.77
# 140232      108.6     4030   多摩川      1800       1             6.77
# 140233      109.9     4521   多摩川      1800       5             6.70
# 140234      109.9     4521   多摩川      1800       5             6.70
# 140235      111.7     3687   多摩川      1800       3             6.80
# 140236      111.7     3687   多摩川      1800       3             6.80
# 140237      112.6     3477   多摩川      1800       2             6.79
# 140238      112.6     3477   多摩川      1800       2             6.79
# 140239      113.6     4103   多摩川      1800       4             6.86
# 140240      113.6     4103   多摩川      1800       4             6.86
# 140241      114.6     3690   多摩川      1800       6             6.79
# 140242      114.6     3690   多摩川      1800       6             6.79
#
#          RACE_DATE
# 0       2020-01-21
# 1       2020-01-21
# 2       2020-01-21
# 3       2020-01-21
# 4       2020-01-21
# 5       2020-01-21
# 6       2020-01-21
# 7       2020-01-21
# 8       2020-01-21
# 9       2020-01-21
# 10      2020-01-21
# 11      2020-01-21
# 12      2020-01-21
# 13      2020-01-21
# 14      2020-01-21
# 15      2020-01-21
# 16      2020-01-21
# 17      2020-01-21
# 18      2020-01-21
# 19      2020-01-21
# 20      2020-01-21
# 21      2020-01-21
# 22      2020-01-21
# 23      2020-01-21
# 24      2020-01-21
# 25      2020-01-21
# 26      2020-01-21
# 27      2020-01-21
# 28      2020-01-21
# 29      2020-01-21
# ...            ...
# 140213  2020-01-10
# 140214  2020-01-10
# 140215  2020-01-10
# 140216  2020-01-10
# 140217  2020-01-10
# 140218  2020-01-10
# 140219  2020-01-10
# 140220  2020-01-10
# 140221  2020-01-10
# 140222  2020-01-10
# 140223  2020-01-10
# 140224  2020-01-10
# 140225  2020-01-10
# 140226  2020-01-10
# 140227  2020-01-10
# 140228  2020-01-10
# 140229  2020-01-10
# 140230  2020-01-10
# 140231  2020-01-10
# 140232  2020-01-10
# 140233  2020-01-10
# 140234  2020-01-10
# 140235  2020-01-10
# 140236  2020-01-10
# 140237  2020-01-10
# 140238  2020-01-10
# 140239  2020-01-10
# 140240  2020-01-10
# 140241  2020-01-10
# 140242  2020-01-10
#
# [140243 rows x 7 columns]
